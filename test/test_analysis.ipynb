# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#load the data
df_complete = pd.read_csv("eval_test.csv")
display(df_complete.info())
display(df_complete)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                200 non-null    int64
#  1   repetition_number         200 non-null    int64
#  2   weight_index              200 non-null    int64
#  3   weight_tuple              200 non-null    object
#  4   num_iterations            200 non-null    int64
#  5   vehicle_id                200 non-null    int64
#  6   normalised_speed_reward   200 non-null    float64
#  7   normalised_energy_reward  200 non-null    float64
#  8   raw_speed_reward          200 non-null    float64
#  9   raw_energy_reward         200 non-null    float64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 15.8+ KB
# None
#      Unnamed: 0  repetition_number  weight_index weight_tuple  num_iterations  \
# 0             0                  0             0   [0.0, 1.0]              50
# 1             1                  0             0   [0.0, 1.0]              50
# 2             2                  1             0   [0.0, 1.0]               8
# 3             3                  1             0   [0.0, 1.0]               8
# 4             4                  2             0   [0.0, 1.0]              50
# ..          ...                ...           ...          ...             ...
# 195         195                  2            19   [1.0, 0.0]              50
# 196         196                  3            19   [1.0, 0.0]              50
# 197         197                  3            19   [1.0, 0.0]              50
# 198         198                  4            19   [1.0, 0.0]               8
# 199         199                  4            19   [1.0, 0.0]               8
#
#      vehicle_id  normalised_speed_reward  normalised_energy_reward  \
# 0             0                 0.259621                  0.965455
# 1             1                -1.000000                 -1.000000
# 2             0                -0.011226                  0.750000
# 3             1                -1.000000                 -1.000000
# 4             0                 0.371696                  0.970909
# ..          ...                      ...                       ...
# 195           1                 0.437313                  0.987273
# 196           0                 0.339703                  0.976364
# 197           1                -0.658447                 -0.601818
# 198           0                -0.023342                  0.750000
# 199           1                -1.000000                 -1.000000
#
#      raw_speed_reward  raw_energy_reward
# 0           12.981040          48.272727
# 1          -50.000000         -50.000000
# 2           -0.089808           6.000000
# 3           -8.000000          -8.000000
# 4           18.584795          48.545455
# ..                ...                ...
# 195         21.865638          49.363636
# 196         16.985147          48.818182
# 197        -32.922354         -30.090909
# 198         -0.186733           6.000000
# 199         -8.000000          -8.000000
#
# [200 rows x 10 columns]

# %%
grouped_df = df_complete.groupby(["vehicle_id","weight_index"])["normalised_speed_reward"].mean()
grouped_df = grouped_df.reset_index()
print(grouped_df)
#sns.scatterplot(grouped_df, x="normalised_speed_reward",hue="vehicle_id")
# Out:
#     vehicle_id  weight_index  normalised_speed_reward
# 0            0             0                 0.178543
# 1            0             1                 0.241044
# 2            0             2                 0.166043
# 3            0             3                 0.217662
# 4            0             4                 0.125467
# 5            0             5                 0.294096
# 6            0             6                 0.111778
# 7            0             7                 0.150660
# 8            0             8                 0.066345
# 9            0             9                 0.171517
# 10           0            10                 0.124666
# 11           0            11                 0.291193
# 12           0            12                 0.267992
# 13           0            13                 0.269293
# 14           0            14                 0.115807
# 15           0            15                 0.186159
# 16           0            16                 0.311661
# 17           0            17                 0.188293
# 18           0            18                 0.205934
# 19           0            19                 0.202065
# 20           1             0                -0.563636
# 21           1             1                -0.126273
# 22           1             2                -0.188673
# 23           1             3                -0.195749
# 24           1             4                -0.719979
# 25           1             5                 0.368027
# 26           1             6                -0.274982
# 27           1             7                 0.120163
# 28           1             8                -0.319395
# 29           1             9                -0.441304
# 30           1            10                 0.254249
# 31           1            11                -0.066534
# 32           1            12                 0.367948
# 33           1            13                 0.112722
# 34           1            14                -0.372357
# 35           1            15                -1.000000
# 36           1            16                 0.051360
# 37           1            17                -0.712695
# 38           1            18                -0.247340
# 39           1            19                -0.644227

# %%
sns.lineplot(grouped_df, x="weight_index",y="num_iterations",hue="vehicle_id")
# Out:
# <Axes: xlabel='weight_index', ylabel='num_iterations'>

# %%
#load the data
df_complete = pd.read_csv("loss_test.csv")
display(df_complete.info())
display(df_complete)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   50000 non-null  int64
#  1   episode      49951 non-null  float64
#  2   loss         49951 non-null  float64
#  3   hypervolume  5 non-null      float64
# dtypes: float64(3), int64(1)
# memory usage: 1.5 MB
# None
#        Unnamed: 0  episode      loss  hypervolume
# 0               0      NaN       NaN     0.061521
# 1               1      NaN       NaN          NaN
# 2               2      NaN       NaN          NaN
# 3               3      NaN       NaN          NaN
# 4               4      NaN       NaN          NaN
# ...           ...      ...       ...          ...
# 49995       49995  49995.0  0.111110          NaN
# 49996       49996  49996.0  0.234974          NaN
# 49997       49997  49997.0  0.121884          NaN
# 49998       49998  49998.0  0.151999          NaN
# 49999       49999  49999.0  0.167275          NaN
#
# [50000 rows x 4 columns]

# %%
sns.lineplot(df_complete, x="episode",y="loss")
# Out:
# <Axes: xlabel='episode', ylabel='loss'>
