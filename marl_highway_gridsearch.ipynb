# %%
from src.MOMA_DQN import MOMA_DQN
import mo_gymnasium as mo_gym
from src.gridsearch import gridsearch
from tqdm.notebook import tqdm
import itertools
import pandas as pd
import numpy as np

# %%
#final environment config used for experiments
env_config = {
    "screen_width": 500,
    "screen_height": 500,
    "vehicles_count": 10,
    "controlled_vehicles": 2,

    "action": {
        "type": "MultiAgentAction",
        "action_config": {
            "type": "DiscreteMetaAction",
        }
    }
}

# run_config = {
#     "env":  [env_config],

#     "init": {
#          "replay_buffer_size": [1000],
#          "batch_ratio" : [0.2],
#          "reward_structure" : ["ego_reward", "mean_reward"],
#          "use_multi_dqn:" : [False,True],
#          "observation_space_name" : ["Kinematics", "OccupancyGrid"],
#     },
#     "train": {
#          "gamma": 0.9,
#          "num_episodes" : 25_000,
#          "inv_target_update_frequency": 10,
#          "epsilon_start": 0.9,
#          "epsilon_end": 0,
#          "epsilon_end_time": 0.75,
#     },
#     "eval": {
#         "num_repetitions": 20,
#         "num_points": 20,
#         "num_evaluations": 10,W
#     },
# }

#test run config for generating example data
run_config = {
    "env":  [env_config],

    "init": {
         "replay_buffer_size": [1000],
         "batch_ratio" : [0.2],
         "reward_structure" : ["ego_reward", "mean_reward"],
         "use_multi_dqn" : [False,True],
         "observation_space_name" : ["Kinematics", "OccupancyGrid"],
    },
    "train": {
         "gamma": 0.9,
         "num_episodes" : 100,
         "inv_target_update_frequency": 10,
         "epsilon_start": 0.9,
         "epsilon_end": 0,
         "epsilon_end_time": 0.75,
         "num_evaluations": 2
    },
    "eval": {
        "num_repetitions": 2,
        "num_points": 3,
    },
}


env = mo_gym.make('moma-highway-env-v0', render_mode='rgb_array')
gridsearch(MOMA_DQN, env, run_config, 11, csv_file_path="data/moma_highway_test/", experiment_name="moma_highway")
# Out:
# Weight tuple:  60%|██████    | 6/10 [00:07<00:05,  1.33s/it]
# Training episodes:   0%|          | 0/100 [00:09<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 69
#      42 run_config = {
#      43     "env":  [env_config],
#      44
#    (...)
#      64     },
#      65 }
#      68 env = mo_gym.make('moma-highway-env-v0', render_mode='rgb_array')
# ---> 69 gridsearch(MOMA_DQN, env, run_config, 11, csv_file_path="data/moma_highway_test/", experiment_name="moma_highway")
#
# File ~/Documents/Master_Project/moma-rl-ad/src/gridsearch.py:120, in gridsearch(algorithm, env, run_config, seed, csv_file_path, experiment_name)
#     118 else:
#     119     agent = algorithm(env = env, num_objectives = 2, seed = seed, observation_space_shape = obs[0].shape, num_actions = 5, objective_names=["speed_reward", "energy_reward"], **parameters)
# --> 120 loss_logger = agent.train(**run_config["train"])
#     121 agent.store_network(csv_file_path, f"{experiment_name}_config_{env_config_id}_exp{experiment_id}.pth")
#     123 #run a final evaluation using the trained agent
#
# File ~/Documents/Master_Project/moma-rl-ad/src/MOMA_DQN.py:223, in MOMA_DQN.train(self, num_episodes, inv_optimisation_frequency, inv_target_update_frequency, gamma, epsilon_start, epsilon_end, epsilon_end_time, num_evaluations, eval_seed)
#     221 #run evaluation
#     222 if (num_evaluations != 0) and (episode_nr % eval_interval == 0):
# --> 223     _,_, hv = self.evaluate(num_repetitions= 5, num_points= 10, hv_reference_point=np.array([0,0]),
#     224                             seed = eval_seed)
#     225     hv_logger.add(episode=episode_nr, hypervolume=hv)
#     227 #update logger, reduce epsilon
#
# File ~/Documents/Master_Project/moma-rl-ad/src/MOMA_DQN.py:544, in MOMA_DQN.evaluate(self, num_repetitions, num_points, hv_reference_point, seed, episode_recording_interval, video_name_prefix, video_location, render_episodes)
#     536     num_close_vehicles = MOMA_DQN.__get_num_close_vehicles(info["vehicle_objective_weights"])
#     537 self.action = self.act(self.obs, eps_greedy=False, num_close_vehicles=num_close_vehicles)
#     538 (
#     539 self.obs,
#     540 self.reward,
#     541 self.terminated,
#     542 self.truncated,
#     543 info,
# --> 544 ) = self.eval_env.step(self.action)
#     546 #accumulate rewards for summary logger
#     547 for vehicle_id in range(self.num_controlled_vehicles):
#     548     #select only the ego rewards for a specific controlled vehicle
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/highway_env/envs/common/abstract.py:237, in AbstractEnv.step(self, action)
#     234 self.time += 1 / self.config["policy_frequency"]
#     235 self._simulate(action)
# --> 237 obs = self.observation_type.observe()
#     238 reward = self._reward(action)
#     239 terminated = self._is_terminated()
#
# File ~/Documents/Master_Project/moma-rl-ad/src/observations.py:53, in AugmentedMultiAgentObservation.observe(self)
#      51 vehicle_lists = []
#      52 for obs_type in self.agents_observation_types:
# ---> 53     obs, vehicle_list = obs_type.observe()
#      54     observations.append(obs)
#      55     vehicle_lists.append(vehicle_list)
#
# File ~/Documents/Master_Project/moma-rl-ad/src/observations.py:175, in AugmentedKinematicObservation.observe(self)
#     173     MAX_SPEED = self.observer_vehicle.MAX_SPEED
#     174     MIN_SPEED = self.observer_vehicle.MIN_SPEED
# --> 175     df = self.normalize_obs(df, MAX_SPEED, MIN_SPEED)
#     176 # Fill missing rows
#     177 if df.shape[0] < self.vehicles_count:
#
# File ~/Documents/Master_Project/moma-rl-ad/src/observations.py:212, in AugmentedKinematicObservation.normalize_obs(self, df, MAX_SPEED, MIN_SPEED)
#     210                 df[feature] = highway_env.utils.lmap(df[feature], [f_range[0], f_range[1]], [-1, 1])
#     211     if self.clip:
# --> 212         df[feature] = np.clip(df[feature], -1, 1)
#     213 return df
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2169, in clip(a, a_min, a_max, out, **kwargs)
#    2100 @array_function_dispatch(_clip_dispatcher)
#    2101 def clip(a, a_min, a_max, out=None, **kwargs):
#    2102     """
#    2103     Clip (limit) the values in an array.
#    2104
#    (...)
#    2167
#    2168     """
# -> 2169     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/pandas/core/generic.py:9098, in NDFrame.clip(self, lower, upper, axis, inplace, **kwargs)
#    9096 # fast-path for scalars
#    9097 if (lower is None or is_number(lower)) and (upper is None or is_number(upper)):
# -> 9098     return self._clip_with_scalar(lower, upper, inplace=inplace)
#    9100 result = self
#    9101 if lower is not None:
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/pandas/core/generic.py:8843, in NDFrame._clip_with_scalar(self, lower, upper, inplace)
#    8839     result = result.where(
#    8840         cond, lower, inplace=inplace
#    8841     )  # type: ignore[assignment]
#    8842 if upper is not None:
# -> 8843     cond = mask | (self <= upper)
#    8844     result = self if inplace else result
#    8845     result = result.where(
#    8846         cond, upper, inplace=inplace
#    8847     )  # type: ignore[assignment]
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/pandas/core/arraylike.py:78, in OpsMixin.__or__(self, other)
#      76 @unpack_zerodim_and_defer("__or__")
#      77 def __or__(self, other):
# ---> 78     return self._logical_method(other, operator.or_)
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/pandas/core/series.py:6131, in Series._logical_method(self, other, op)
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6130 res_values = ops.logical_op(lvalues, rvalues, op)
# -> 6131 return self._construct_result(res_values, name=res_name)
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/pandas/core/series.py:6231, in Series._construct_result(self, result, name)
#    6228 # TODO: result should always be ArrayLike, but this fails for some
#    6229 #  JSONArray tests
#    6230 dtype = getattr(result, "dtype", None)
# -> 6231 out = self._constructor(result, index=self.index, dtype=dtype, copy=False)
#    6232 out = out.__finalize__(self)
#    6234 # Set the result's name after __finalize__ is called because __finalize__
#    6235 #  would set it back to self.name
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/pandas/core/series.py:593, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     590         data = SingleArrayManager.from_array(data, index)
#     592 NDFrame.__init__(self, data)
# --> 593 self.name = name
#     594 self._set_axis(0, index)
#     596 if original_dtype is None and is_pandas_object and data_dtype == np.object_:
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/pandas/core/generic.py:6320, in NDFrame.__setattr__(self, name, value)
#    6317 # if this fails, go on to more involved attribute setting
#    6318 # (note that this matches __getattr__, above).
#    6319 if name in self._internal_names_set:
# -> 6320     object.__setattr__(self, name, value)
#    6321 elif name in self._metadata:
#    6322     object.__setattr__(self, name, value)
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/pandas/core/series.py:786, in Series.name(self, value)
#     784 @name.setter
#     785 def name(self, value: Hashable) -> None:
# --> 786     validate_all_hashable(value, error_name=f"{type(self).__name__}.name")
#     787     object.__setattr__(self, "_name", value)
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/pandas/core/dtypes/common.py:1590, in validate_all_hashable(error_name, *args)
#    1571 def validate_all_hashable(*args, error_name: str | None = None) -> None:
#    1572     """
#    1573     Return None if all args are hashable, else raise a TypeError.
#    1574
#    (...)
#    1588     None
#    1589     """
# -> 1590     if not all(is_hashable(arg) for arg in args):
#    1591         if error_name:
#    1592             raise TypeError(f"{error_name} must be a hashable type")
#
# File ~/Documents/Master_Project/moma-rl-ad/venv/lib/python3.12/site-packages/pandas/core/dtypes/common.py:1590, in <genexpr>(.0)
#    1571 def validate_all_hashable(*args, error_name: str | None = None) -> None:
#    1572     """
#    1573     Return None if all args are hashable, else raise a TypeError.
#    1574
#    (...)
#    1588     None
#    1589     """
# -> 1590     if not all(is_hashable(arg) for arg in args):
#    1591         if error_name:
#    1592             raise TypeError(f"{error_name} must be a hashable type")
#
# KeyboardInterrupt:

# %%
#load the data
df_complete = pd.read_csv("data/moma_highway_test/moma_highway_merged_loss.csv")
display(df_complete.info())
display(df_complete[~df_complete["hypervolume"].isna()])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              400 non-null    int64
#  1   episode                 323 non-null    float64
#  2   loss                    323 non-null    float64
#  3   hypervolume             8 non-null      float64
#  4   env_config_id           400 non-null    int64
#  5   experiment_id           400 non-null    int64
#  6   replay_buffer_size      400 non-null    int64
#  7   batch_ratio             400 non-null    float64
#  8   reward_structure        400 non-null    object
#  9   observation_space_name  400 non-null    object
# dtypes: float64(4), int64(4), object(2)
# memory usage: 31.4+ KB
# None
#      Unnamed: 0  episode      loss  hypervolume  env_config_id  experiment_id  \
# 0             0      NaN       NaN     0.279336              0              0
# 50           50     50.0  0.180082     0.292104              0              0
# 100           0      NaN       NaN     0.155550              0              1
# 150          50     50.0  0.189552     0.255295              0              1
# 200           0      NaN       NaN     0.150507              0              2
# 250          50     50.0  0.102636     0.152172              0              2
# 300           0      NaN       NaN     0.154508              0              3
# 350          50     50.0  0.120965     0.077062              0              3
#
#      replay_buffer_size  batch_ratio reward_structure observation_space_name
# 0                  1000          0.2       ego_reward             Kinematics
# 50                 1000          0.2       ego_reward             Kinematics
# 100                1000          0.2       ego_reward          OccupancyGrid
# 150                1000          0.2       ego_reward          OccupancyGrid
# 200                1000          0.2      mean_reward             Kinematics
# 250                1000          0.2      mean_reward             Kinematics
# 300                1000          0.2      mean_reward          OccupancyGrid
# 350                1000          0.2      mean_reward          OccupancyGrid
